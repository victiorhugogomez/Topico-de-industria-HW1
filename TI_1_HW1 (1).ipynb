# %% [markdown]
# # Homework 1
#
# **Name:** -- Victor Hugo Gomez Soto --
#
# **e-mail:** -- victor.gomez2701@alumnos.udg.mx --

# %% [markdown]
# # MODULES

# %%
# Load modules
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

# %% [markdown]
# # Theory on the Gradient Descent algorithm

# %%
# 📌 Importar la librería numpy para manejar operaciones matemáticas
import numpy as np

# 📌 Definir la función que queremos minimizar
def function(x, y):
    """
    Esta función matemática recibe dos valores (x, y) y devuelve 
    el resultado de la ecuación f(x, y) = x² + y² + sin(3x) + cos(3y).
    """
    return x**2 + y**2 + np.sin(3*x) + np.cos(3*y)

# 📌 Crear una malla de valores para graficar la función en 3D
x = np.linspace(-2, 2, 50)  # Genera 50 valores equidistantes entre -2 y 2 para el eje X
y = np.linspace(-2, 2, 50)  # Genera 50 valores equidistantes entre -2 y 2 para el eje Y
X, Y = np.meshgrid(x, y)    # Crea una malla combinando los valores de X y Y para evaluar la función
Z = function(X, Y)          # Calcula los valores de la función en toda la malla

# 📌 Graficar la función en 3D
import matplotlib.pyplot as plt  # Importar librería para visualización de gráficos

fig = plt.figure(figsize=(10, 6))  # Crea una figura de 10x6 pulgadas para la gráfica
ax = fig.add_subplot(111, projection='3d')  # Agrega un gráfico en 3D a la figura

# 📌 Dibujar la superficie de la función en 3D
ax.plot_surface(X, Y, Z, cmap='viridis', alpha=0.7)  
# - `cmap='viridis'` establece la escala de colores de la superficie
# - `alpha=0.7` ajusta la transparencia (1 = opaco, 0 = totalmente transparente)

# 📌 Configurar etiquetas de los ejes
ax.set_xlabel('X')  # Etiqueta para el eje X
ax.set_ylabel('Y')  # Etiqueta para el eje Y
ax.set_zlabel('f(x, y)')  # Etiqueta para el eje Z (altura de la función)
ax.set_title('Superficie de la función')  # Título de la gráfica

# 📌 Imprimir la función en la consola
print("f(x, y) = x^2 + y^2 + sin(3x) + cos(3y)")  

# 📌 Mostrar la gráfica
plt.show()
# Out:
# f(x, y) = x^2 + y^2 + sin(3x) + cos(3y)

# %%
# 📌 Definir el gradiente de la función (derivadas parciales)
def gradient(x, y):
    """
    Calcula el gradiente (vector de derivadas parciales) de la función f(x, y).
    
    - df_dx: Derivada parcial respecto a x → Representa la pendiente en la dirección X.
    - df_dy: Derivada parcial respecto a y → Representa la pendiente en la dirección Y.
    
    Devuelve un array con ambas derivadas parciales.
    """
    df_dx = 2*x + 3*np.cos(3*x)  # Derivada parcial respecto a x
    df_dy = 2*y - 3*np.sin(3*y)  # Derivada parcial respecto a y
    return np.array([df_dx, df_dy])  # Devuelve el gradiente como un vector

# 📌 Definir los parámetros del algoritmo de descenso de gradiente
learning_rate = 0.1  # Se define la tasa de aprendizaje, que controla el tamaño del ajuste en cada paso del descenso de gradiente
num_iterations = 50  # Se establece el número total de iteraciones del algoritmo

# 📌 Inicializar el punto de partida del descenso de gradiente
x, y = np.random.uniform(-2, 2, 2)  # Se generan dos valores aleatorios dentro del rango [-2, 2] para X y Y
# Esto permite que el descenso de gradiente comience desde diferentes posiciones cada vez que se ejecuta,
# ayudando a explorar distintas trayectorias hacia el mínimo de la función.

trayectoria = [(x, y)]  # Se crea una lista para almacenar la trayectoria del descenso de gradiente

# 📌 Ejecutar el algoritmo de descenso de gradiente
for _ in range(num_iterations):  # Se repite el proceso durante el número de iteraciones definido anteriormente
    grad = gradient(x, y)  # Se calcula el gradiente de la función en la posición actual (x, y)
    
    x -= learning_rate * grad[0]  # Se actualiza el valor de X restando el gradiente escalado por la tasa de aprendizaje
    y -= learning_rate * grad[1]  # Se actualiza el valor de Y restando el gradiente escalado por la tasa de aprendizaje
    
    trayectoria.append((x, y))  # Se almacena el nuevo punto en la lista de trayectoria

# 📌 Convertir la trayectoria a un array para facilitar su análisis y visualización
trayectoria = np.array(trayectoria)  # Se convierte la lista de puntos en un array de NumPy

# %%
# 📌 Graficar la superficie de la función junto con la trayectoria del descenso de gradiente

# 📌 Crear una nueva figura con tamaño de 10x6 pulgadas
fig = plt.figure(figsize=(10, 6))  

# 📌 Agregar un gráfico en 3D dentro de la figura
ax = fig.add_subplot(111, projection='3d')

# 📌 Crear la malla de valores nuevamente para graficar la superficie de la función
X = np.linspace(-2, 2, 50)  # Se generan 50 valores equidistantes en el rango [-2, 2] para X
Y = np.linspace(-2, 2, 50)  # Se generan 50 valores equidistantes en el rango [-2, 2] para Y
X, Y = np.meshgrid(X, Y)    # Se crea una malla de coordenadas a partir de los valores de X e Y
Z = function(X, Y)          # Se evalúa la función en cada punto de la malla

# 📌 Graficar la superficie de la función
ax.plot_surface(X, Y, Z, cmap='viridis', alpha=0.7)
# - `cmap='viridis'` define el esquema de colores de la superficie.
# - `alpha=0.7` hace la superficie un poco transparente para visualizar mejor la trayectoria.

# 📌 Graficar la trayectoria del descenso de gradiente sobre la superficie
ax.plot(trayectoria[:, 0], trayectoria[:, 1], function(trayectoria[:, 0], trayectoria[:, 1]), 
        'ro-', markersize=5)
# - `trayectoria[:, 0]` → Coordenadas X de la trayectoria.
# - `trayectoria[:, 1]` → Coordenadas Y de la trayectoria.
# - `function(trayectoria[:, 0], trayectoria[:, 1])` → Valor de la función en cada punto de la trayectoria.
# - `'ro-'` → Puntos rojos (`r`), con líneas (`-`) conectándolos.
# - `markersize=4` → Tamaño de los marcadores en la trayectoria.

# 📌 Etiquetas de los ejes y título del gráfico
ax.set_xlabel('X')  # Etiqueta del eje X
ax.set_ylabel('Y')  # Etiqueta del eje Y
ax.set_zlabel('Function Value')  # Etiqueta del eje Z (valor de la función)
ax.set_title('Descenso de Gradiente')  # Título del gráfico

# 📌 Mostrar los valores analizados en cada iteración del descenso de gradiente

# 📌 Crear un DataFrame con las posiciones analizadas en cada iteración
df = pd.DataFrame(trayectoria, columns=["x", "y"])  # Se almacena la trayectoria en un DataFrame
df["Function Value"] = function(df["x"], df["y"])  # Se evalúa la función en cada punto de la trayectoria

# 📌 Mostrar información sobre la función utilizada
print("f(x, y) = x^2 + y^2 + sin(3x) + cos(3y)")  # Imprime la ecuación de la función optimizada
print("Valores analizados en el descenso de gradiente:")
print(df.head(10))  # Muestra solo las primeras 10 iteraciones de la trayectoria

# 📌 Mostrar el gráfico
plt.show()
# Out:
# f(x, y) = x^2 + y^2 + sin(3x) + cos(3y)
# Valores analizados en el descenso de gradiente:
#           x         y  Function Value
# 0 -1.884626 -0.810254        4.039091
# 1 -1.750231 -0.843942        3.814345
# 2 -1.553989 -0.846956        3.306020
# 3 -1.228072 -0.847137        1.916951
# 4 -0.725550 -0.847147       -0.403185
# 5 -0.409601 -0.847148       -0.881907
# 6 -0.428291 -0.847148       -0.883560
# 7 -0.427246 -0.847148       -0.883566
# 8 -0.427312 -0.847148       -0.883566
# 9 -0.427308 -0.847148       -0.883566

# %% [markdown]
# ## Implementación del Descenso de Gradiente
#
# Este notebook implementa el algoritmo de **descenso de gradiente**, un método utilizado para encontrar el **mínimo de una función matemática** de manera eficiente.
#
# ### 📌 ¿Qué es el Descenso de Gradiente?
# El descenso de gradiente es una forma de encontrar el punto más bajo en una superficie matemática.
# Imagina que estás en la cima de una montaña y quieres bajar al valle más profundo. **¿Cómo lo harías?**
# - Mirarías a tu alrededor y elegirías la dirección donde la pendiente es más inclinada hacia abajo.
# - Darías un paso en esa dirección.
# - Repetirías el proceso hasta llegar a un punto donde la pendiente ya no descienda más.
#
# Este mismo principio se aplica en matemáticas y computación para encontrar los valores óptimos en una función.
#
# ### 🏁 ¿Cómo funciona el Descenso de Gradiente?
# 1. **Elegimos un punto inicial aleatorio en la superficie de la función.**
# 2. **Calculamos la pendiente (gradiente) en ese punto.**
# 3. **Nos movemos en la dirección contraria a la pendiente (bajamos la montaña).**
# 4. **Repetimos este proceso varias veces hasta encontrar un mínimo.**
#
# 💡 **Ejemplo real:**
# Piensa en una pelota rodando por una colina. La gravedad hace que se mueva hacia abajo hasta detenerse en el punto más bajo.
# El descenso de gradiente hace lo mismo, pero con números y funciones matemáticas.
#
# ### ✍️ Aplicación en este notebook:
# 1. **Definimos una función matemática en 2D:**
#    \[
#    f(x, y) = x^2 + y^2 + \sin(3x) + \cos(3y)
#    \]
# 2. **Calculamos su gradiente (pendiente en cada punto).**
# 3. **Aplicamos el descenso de gradiente.**
# 4. **Visualizamos la trayectoria en una gráfica 3D.**
#    - Los puntos rojos muestran el camino que siguió el algoritmo hasta llegar al mínimo.
#
# En la gráfica final, podemos ver cómo el algoritmo encuentra el punto más bajo de la función, igual que si estuviéramos bajando una montaña en la vida real.
#
# Una pregunta que me surge es como exactamente esto se aplica a optimizacion de algoritmos
